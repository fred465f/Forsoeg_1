# %%
# Make necessary imports
from Lab import *

# %%
# Make virtual lab
lab = Lab()
# Out:
#         Imported packages and functions:
#         -----------------------------------------
#         Imported matplotlib.pyplot as plt
#         and imported numpy as np
#         and imported pandas as pd
#         and imported numpy.fft as fft
#         and imported seaborn as sns
#         and imported time
#         and imported curve_fit from scipy.optimize

# %%
# Load experiment data
df_glas_til_luft = pd.read_csv('Samlet_glas_til_luft_df.csv')
df_luft_til_glas = pd.read_csv('Samlet_luft_til_glas_df.csv')

df_luft_til_glas
# Out:
#    Angle_small  Angle_alpha  Angle_big_t  Angle_big_r   Coff_Rp  Coff_Rp_err  \
# 0           40          0.5           14          101  0.003581     0.007638
# 1           45          0.5           16           91  0.005081     0.007379
# 2           50          0.5           18           81  0.002500     0.011643
# 3           55          0.5           21           71 -0.001737     0.008451
# 4           60          0.5           24           61  0.000838     0.008702
# 5           65          0.5           27           51  0.009197     0.011283
# 6           70          0.5           30           41  0.026208     0.006000
# 7           75          0.5           34           31  0.075747     0.009714
# 8           80          0.5           38           21  0.167056     0.008409
#
#     Coff_Rs  Coff_Rs_err   Coff_Tp  Coff_Tp_err   Coff_Ts  Coff_Ts_err
# 0  0.008828     0.004561  1.010111     0.010200  0.186644     0.005032
# ...

# %%
# ------------------------------------------------------------
# Glass to air experiment data transformation
# ------------------------------------------------------------

# Define function to let Angle_big --> Angle_2 (theta_2)
def convert_gta_t(x):
    return x[0] - (180 - x[2])

# Define function to transform angles --> sine(angles * 2pi/360)
def sine_gta(x): 
    return np.sin(x * 2*np.pi/360)

# Define function to propagate error for Angle_2 --> sine(Angle_2 * 2pi/360)
def error_prop_gta_t(x): 
    return (2*np.pi/360 * np.cos(x[1] * 2*np.pi/360))**2 * (x[2])**2

#def error_prop_gta_r(x): 
 #   return (2*np.pi/360 * np.cos(x[1] * 2*np.pi/360))**2 * (x[2])**2

# Apply functions to data
df_glas_til_luft['Angle_2_t'] = df_glas_til_luft.apply(convert_gta_t, axis = 1)
df_glas_til_luft['Angle_2_r'] = df_glas_til_luft.apply(convert_gta_r, axis = 1)
df_glas_til_luft['Angle_2_sine_t'] = df_glas_til_luft['Angle_2_t'].apply(sine_gta)
df_glas_til_luft['Angle_2_sine_r'] = df_glas_til_luft['Angle_2_r'].apply(sine_gta)
df_glas_til_luft['Angle_small_sine'] = df_glas_til_luft['Angle_small'].apply(sine_gta)
df_glas_til_luft['Angle_alpha_sine_prop'] = df_glas_til_luft.apply(error_prop_gta_t, axis = 1)

df_glas_til_luft
# Out:
#    Angle_small  Angle_big  Angle_alpha  Angle_big_t  Angle_big_r   Coff_Rp  \
# 0           15          6          0.5            6          152  0.011524
# 1           20          9          0.5            9          142  0.005317
# 2           25         12          0.5           12          133  0.005818
# 3           30         15          0.5           15          122 -0.000141
# 4           32         17          0.5           17          119  0.002838
# 5           34         19          0.5           19          115  0.001712
# 6           36         21          0.5           21          110 -0.000987
# 7           38         24          0.5           24          106  0.003499
# 8           40         28          0.5           28          102  0.009293
#
#    Coff_Rp_err   Coff_Rs  Coff_Rs_err   Coff_Tp  Coff_Tp_err   Coff_Ts  \
# 0     0.009936  0.009250     0.005992  0.654152     0.011862  0.446203
# 1     0.005397  0.010748     0.004218  0.672453     0.006435  0.480243
# ...

# %%
# ------------------------------------------------------------
# Air to glass experiment data transformation
# ------------------------------------------------------------

# Define function to let Angle_big --> Angle_2 (theta_2)
# Value np.pi changed to 180 as columns are in degrees
def convert_gta_t(x):
    return x[0] - (180 - x[2])

def convert_gta_r(x):
    return x[0] - (180 - x[3])

# Define function to transform angles --> sine(angles * 2pi/360)
def sine_gta(x): 
    return np.sin(x * 2*np.pi/360)

# Define function to propagate error for Angle_2 --> sine(Angle_2 * 2pi/360)
def error_prop_gta(x): 
    return (2*np.pi/360 * np.cos(x[1] * 2*np.pi/360))**2 * (x[2])**2

# Apply functions to data
df_luft_til_glas['Angle_2_t'] = df_luft_til_glas.apply(convert_gta_t, axis = 1)
df_luft_til_glas['Angle_2_r'] = df_luft_til_glas.apply(convert_gta_r, axis = 1)
df_luft_til_glas['Angle_2_sine_t'] = df_luft_til_glas['Angle_2_t'].apply(sine_gta)
df_luft_til_glas['Angle_2_sine_r'] = df_luft_til_glas['Angle_2_r'].apply(sine_gta)
df_luft_til_glas['Angle_small_sine'] = df_luft_til_glas['Angle_small'].apply(sine_gta)
df_luft_til_glas['Angle_alpha_sine_prop'] = df_luft_til_glas.apply(error_prop_gta, axis = 1)
df_luft_til_glas
# Out:
#    Angle_small  Angle_alpha  Angle_big_t  Angle_big_r   Coff_Rp  Coff_Rp_err  \
# 0           40          0.5           14          101  0.003581     0.007638
# 1           45          0.5           16           91  0.005081     0.007379
# 2           50          0.5           18           81  0.002500     0.011643
# 3           55          0.5           21           71 -0.001737     0.008451
# 4           60          0.5           24           61  0.000838     0.008702
# 5           65          0.5           27           51  0.009197     0.011283
# 6           70          0.5           30           41  0.026208     0.006000
# 7           75          0.5           34           31  0.075747     0.009714
# 8           80          0.5           38           21  0.167056     0.008409
#
#     Coff_Rs  Coff_Rs_err   Coff_Tp  Coff_Tp_err   Coff_Ts  Coff_Ts_err  \
# 0  0.008828     0.004561  1.010111     0.010200  0.186644     0.005032
# ...

# %%
# Print resulting data frames
df_luft_til_glas.head()

# %%
# Print resulting data frames
df_glas_til_luft.head()

# %%
# Add experiments to virtual lab
lab.add_experiment(name = 'glas_til_luft', data = df_glas_til_luft)
lab.add_experiment(name = 'luft_til_glas', data = df_luft_til_glas)

# %%
# Define model for 'glas_til_luft' and 'luft_til_glas'
n_air = 1
def theta_1_gta(theta_2, n_glass):
    return n_air/n_glass * theta_2
def theta_1_atg(theta_2, n_glass):
    return n_glass/n_air * theta_2

# Define variables
columns = [['Angle_2_sine', 'Angle_small_sine']]
funcs_gta = [theta_1_gta]
funcs_atg = [theta_1_atg]
errors_gta = [df_glas_til_luft['Angle_alpha_sine_prop']]
errors_atg = [df_luft_til_glas['Angle_alpha_sine_prop']]

# Fit for refractive index of optic glass
popts_gta, perrs_gta = lab.fit(name = 'glas_til_luft', columns = columns, 
        funcs = funcs_gta, guesses=1.5, sigma=errors_gta, 
        absolute_sigma=True, residuals=True, 
        save=False, alpha=1)
popts_atg, perrs_atg = lab.fit(name = 'luft_til_glas', columns = columns, 
        funcs = funcs_atg, guesses=1.5, sigma=errors_atg, 
        absolute_sigma=True, residuals=True, 
        save=False, alpha=1)

# %%
# Calculate refrative index of glass directly
df_glas_til_luft['n_glas'] = df_glas_til_luft.apply(lambda x: x[12]/x[13], axis = 1)
df_luft_til_glas['n_glas'] = df_luft_til_glas.apply(lambda x: x[13]/x[12], axis = 1)
n_glas_gta = df_glas_til_luft['n_glas'].mean()
n_glas_atg = df_luft_til_glas['n_glas'].mean()
print(n_glas_gta, n_glas_atg)
