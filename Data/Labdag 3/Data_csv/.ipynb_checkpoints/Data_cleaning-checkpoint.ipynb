# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
from scipy.optimize import curve_fit
import pandas as pd
import glob
import seaborn as sns

df_data = pd.read_csv('Data_glas_til_luft.csv')
df_back = pd.read_csv('Data_glas_til_luft_baggrund.csv')

df_back['Volt'] = 10**(-3)* df_back['Volt_mV']
df_back['Volt_alpha'] = 10**(-3)* df_back['Volt_alpha_mV']
df_data['Volt_alpha'] = 10**(-3)* df_data['Volt_alpha_mV']
df_data
# Out:
#     Angle_small  Angle_big  Angle_alpha Polarization Reflected/Transmitted  \
# 0            15          6          0.5            p                     t
# 1            15          6          0.5            s                     t
# 2            15        152          0.5            p                     r
# 3            15        152          0.5            s                     r
# 4            20          9          0.5            p                     t
# 5            20          9          0.5            s                     t
# 6            20        142          0.5            p                     r
# 7            20        142          0.5            s                     r
# 8            25         12          0.5            p                     t
# 9            25         12          0.5            s                     t
# 10           25        133          0.5            p                     r
# 11           25        133          0.5            s                     r
# 12           30         15          0.5            p                     t
# 13           30         15          0.5            s                     t
# 14           30        122          0.5            p                     r
# 15           30        122          0.5            s                     r
# 16           32         17          0.5            p                     t
# 17           32         17          0.5            s                     t
# 18           32        119          0.5            p                     r
# 19           32        119          0.5            s                     r
# 20           34         19          0.5            p                     t
# 21           34         19          0.5            s                     t
# 22           34        115          0.5            p                     r
# 23           34        115          0.5            s                     r
# 24           36         21          0.5            p                     t
# 25           36         21          0.5            s                     t
# 26           36        110          0.5            p                     r
# 27           36        110          0.5            s                     r
# 28           38         24          0.5            p                     t
# 29           38         24          0.5            s                     t
# 30           38        106          0.5            p                     r
# 31           38        106          0.5            s                     r
# 32           40         28          0.5            p                     t
# 33           40         28          0.5            s                     t
# 34           40        102          0.5            p                     r
# 35           40        102          0.5            s                     r
# 36           42         33          0.5            p                     t
# 37           42         33          0.5            s                     t
# 38           42         98          0.5            p                     r
# 39           42         98          0.5            s                     r
#
#      Volt_V  Volt_alpha_mV  Volt_alpha
# 0   1.31000         17.760    0.017760
# 1   2.69200         28.750    0.028750
# 2   0.03051         17.610    0.017610
# 3   0.06319         19.580    0.019580
# 4   1.33800         10.090    0.010090
# 5   2.88800         18.950    0.018950
# 6   0.01982          3.180    0.003180
# 7   0.07378         11.430    0.011430
# 8   1.25600         11.770    0.011770
# 9   2.63500         17.300    0.017300
# 10  0.01958          8.428    0.008428
# 11  0.08435         10.310    0.010310
# 12  1.21100          8.660    0.008660
# 13  2.35000         14.940    0.014940
# 14  0.01166          6.745    0.006745
# 15  0.14010          3.641    0.003641
# 16  1.13400         18.270    0.018270
# 17  2.22800         17.660    0.017660
# 18  0.01719         17.740    0.017740
# 19  0.17888         18.360    0.018360
# 20  1.11500          5.140    0.005140
# 21  2.13600         16.270    0.016270
# 22  0.01483         14.090    0.014090
# 23  0.21270          9.043    0.009043
# 24  0.95410          3.014    0.003014
# 25  1.63500         11.660    0.011660
# 26  0.00724          3.039    0.003039
# 27  0.20340         10.550    0.010550
# 28  0.82580          6.236    0.006236
# 29  1.35700          6.543    0.006543
# 30  0.01687         11.540    0.011540
# 31  0.27900         10.750    0.010750
# 32  0.64420          6.995    0.006995
# 33  1.01000         14.320    0.014320
# 34  0.02422          6.014    0.006014
# 35  0.29410          2.483    0.002483
# 36  0.48200         14.040    0.014040
# 37  0.69590          7.332    0.007332
# 38  0.94920          8.549    0.008549
# 39  0.60840          9.045    0.009045

# %%
#Splitter DataFrame afhængigt af polarisation of refleksion/transmission. NB: Kan forbedres
df_p_t = df_data[(df_data['Polarization'] == 'p') & (df_data['Reflected/Transmitted'] == 't')]
df_p_r = df_data[(df_data['Polarization'] == 'p') & (df_data['Reflected/Transmitted'] == 'r')]

df_s_t = df_data[(df_data['Polarization'] == 's') & (df_data['Reflected/Transmitted'] == 't')]
df_s_r = df_data[(df_data['Polarization'] == 's') & (df_data['Reflected/Transmitted'] == 'r')]

df_t_back = df_back[(df_back['Reflected/Transmitted'] == 't')]
df_r_back = df_back[(df_back['Reflected/Transmitted'] == 'r')]

df_p_t.reset_index(drop=True,inplace=True)
df_p_r.reset_index(drop=True,inplace=True)
df_s_t.reset_index(drop=True,inplace=True)
df_s_r.reset_index(drop=True,inplace=True)
df_t_back.reset_index(drop=True,inplace=True)
df_r_back.reset_index(drop=True,inplace=True)

df_s_r
# Out:
#    Angle_small  Angle_big  Angle_alpha Polarization Reflected/Transmitted  \
# 0           15        152          0.5            s                     r
# 1           20        142          0.5            s                     r
# 2           25        133          0.5            s                     r
# 3           30        122          0.5            s                     r
# 4           32        119          0.5            s                     r
# 5           34        115          0.5            s                     r
# 6           36        110          0.5            s                     r
# 7           38        106          0.5            s                     r
# 8           40        102          0.5            s                     r
# 9           42         98          0.5            s                     r
#
#     Volt_V  Volt_alpha_mV  Volt_alpha
# 0  0.06319         19.580    0.019580
# 1  0.07378         11.430    0.011430
# 2  0.08435         10.310    0.010310
# 3  0.14010          3.641    0.003641
# 4  0.17888         18.360    0.018360
# 5  0.21270          9.043    0.009043
# 6  0.20340         10.550    0.010550
# 7  0.27900         10.750    0.010750
# 8  0.29410          2.483    0.002483
# 9  0.60840          9.045    0.009045

# %%
#Nye DFs konstrueres
df_p_t_corr = df_p_t[['Angle_small','Angle_big','Angle_alpha']].copy()
df_p_t_corr['Volt_Corr'] = df_p_t['Volt_V'] - df_t_back['Volt']
df_p_t_corr['Error1'] = df_p_t['Volt_alpha'].copy()
df_p_t_corr['Error2'] = df_t_back['Volt']


df_p_r_corr = df_p_r[['Angle_small','Angle_big','Angle_alpha']].copy()
df_p_r_corr['Volt_Corr'] = df_p_r['Volt_V'] - df_r_back['Volt']
df_p_r_corr['Error1'] = df_p_r['Volt_alpha'].copy()
df_p_r_corr['Error2'] = df_r_back['Volt']

df_s_t_corr = df_s_t[['Angle_small','Angle_big','Angle_alpha']].copy()
df_s_t_corr['Volt_Corr'] = df_s_t['Volt_V'] - df_t_back['Volt']
df_s_t_corr['Error1'] = df_s_t['Volt_alpha'].copy()
df_s_t_corr['Error2'] = df_t_back['Volt']

df_s_r_corr = df_s_r[['Angle_small','Angle_big','Angle_alpha']].copy()
df_s_r_corr['Volt_Corr'] = df_s_r['Volt_V'] - df_r_back['Volt']
df_s_r_corr['Error1'] = df_s_r['Volt_alpha'].copy()
df_s_r_corr['Error2'] = df_r_back['Volt']
df_s_r_corr
# Out:
#    Angle_small  Angle_big  Angle_alpha  Volt_Corr    Error1    Error2
# 0           15        152          0.5   0.055498  0.019580  0.007692
# 1           20        142          0.5   0.064487  0.011430  0.009293
# 2           25        133          0.5   0.076290  0.010310  0.008060
# 3           30        122          0.5   0.128160  0.003641  0.011940
# 4           32        119          0.5   0.167310  0.018360  0.011570
# 5           34        115          0.5   0.201260  0.009043  0.011440
# 6           36        110          0.5   0.194205  0.010550  0.009195
# 7           38        106          0.5   0.269058  0.010750  0.009942
# 8           40        102          0.5   0.288280  0.002483  0.005820
# 9           42         98          0.5   0.598950  0.009045  0.009450

# %%
def propagate(x):
    return np.sqrt(x[4]**2 + x[5]**2)
    
df_p_t_corr['Err_prop'] = df_p_t_corr.apply(propagate, axis = 1)
df_p_r_corr['Err_prop'] = df_p_r_corr.apply(propagate, axis = 1)
df_s_t_corr['Err_prop'] = df_s_t_corr.apply(propagate, axis = 1)
df_s_r_corr['Err_prop'] = df_s_r_corr.apply(propagate, axis = 1)

Ip0 = df_p_t_corr.iloc[0][2]
Is0 = df_s_t_corr.iloc[0][2] 

Ip_err = df_p_t_corr.iloc[0][-1]
Is_err = df_s_t_corr.iloc[0][-1]

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.errorbar(x=df_p_r_corr['Angle_small'],y=df_p_r_corr['Volt_Corr'],
             fmt='o',mfc='r',mec='r',ms=8,
             xerr=df_p_r_corr['Angle_alpha'],yerr=df_p_r_corr['Err_prop'], 
             ecolor='k')
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.errorbar(x=df_s_r_corr['Angle_small'],y=df_s_r_corr['Volt_Corr'],
             fmt='o',mfc='r',mec='r',ms=8,
             xerr=df_s_r_corr['Angle_alpha'],yerr=df_s_r_corr['Err_prop'], 
             ecolor='k')
ax.grid()

# %%
df_p_t_corr

df_s_t_corr
# Out:
#    Angle_small  Angle_big  Angle_alpha  Volt_Corr    Error1    Error2  \
# 0           15          6          0.5   2.677220  0.028750  0.014780
# 1           20          9          0.5   2.881457  0.018950  0.006543
# 2           25         12          0.5   2.619890  0.017300  0.015110
# 3           30         15          0.5   2.340307  0.014940  0.009693
# 4           32         17          0.5   2.218748  0.017660  0.009252
# 5           34         19          0.5   2.123120  0.016270  0.012880
# 6           36         21          0.5   1.625899  0.011660  0.009101
# 7           38         24          0.5   1.347780  0.006543  0.009220
# 8           40         28          0.5   0.997550  0.014320  0.012450
# 9           42         33          0.5   0.686789  0.007332  0.009111
#
#    Err_prop
# 0  0.032327
# 1  0.020048
# 2  0.022970
# 3  0.017809
# 4  0.019937
# 5  0.020751
# 6  0.014791
# 7  0.011306
# 8  0.018975
# 9  0.011695

# %%
#intensiteter beregnes
dfs_s = [df_s_t_corr, df_s_r_corr]
dfs_p = [df_p_t_corr, df_p_r_corr]
def intensity_p(x):
    return x[2]/(df_p_t_corr.iloc[0][2])
def intensity_s(x):
    return x[2]/(df_s_t_corr.iloc[0][2])

vals_s = []
for x in dfs_s:
    a = x.apply(intensity_s, axis = 1)
    vals_s.append(a)

vals_p = []
for x in dfs_p:
    a = x.apply(intensity_p, axis = 1)
    vals_p.append(a)

# %%
#intensiteter klaskes på
df_s_t_corr['Coff'] = vals_s[0]
df_s_r_corr['Coff'] = vals_s[1]

df_p_t_corr['Coff'] = vals_p[0]
df_p_r_corr['Coff'] = vals_p[1]

# %%
#Reduktion af t df'erne - kør en gang
df_p_t_corr.drop([0,1,2],inplace=True)
df_p_t_corr.reset_index(drop=True,inplace=True)

df_s_t_corr.drop([0,1,2],inplace=True)
df_s_t_corr.reset_index(drop=True,inplace=True)

# %%
#Sum R + T
a = df_p_t_corr['Coff'] + df_p_r_corr['Coff'] 
b = df_s_t_corr['Coff'] + df_s_r_corr['Coff']

# %%
def err_prop_p(x):
    return (1/abs(Ip0))*np.sqrt(x[-2]**2 + (x[2]/Ip0)**2*Ip_err**2)

def err_prop_s(x):
    return (1/abs(Is0))*np.sqrt(x[-2]**2 + (x[2]/Is0)**2*Is_err**2)

err_p = []
for x in dfs_p:
    a = x.apply(err_prop_p, axis = 1)
    err_p.append(a)

err_s = []
for x in dfs_s:
    a = x.apply(err_prop_s, axis = 1)
    err_s.append(a)

# %%
df_s_t_corr['Err_Coff'] = err_s[0]
df_s_r_corr['Err_Coff'] = err_s[1]

df_p_t_corr['Err_Coff'] = err_p[0]
df_p_r_corr['Err_Coff'] = err_p[1]

# %%
#Sketch
fig, ax = plt.subplots(figsize=(10,5))
plt.errorbar(x=df_p_r_corr['Angle'],y=df_p_r_corr['Coff'],
             fmt='o',mfc='r',mec='r',ms=8,
             xerr=df_p_r_corr['Angle_alpha'],yerr=df_p_r_corr['Err_Coff'], 
             ecolor='k',label='R_p')

plt.errorbar(x=df_s_r_corr['Angle'],y=df_s_r_corr['Coff'],
             fmt='o',mfc='b',mec='b',ms=8,
             xerr=df_s_r_corr['Angle_alpha'],yerr=df_s_r_corr['Err_Coff'], 
             ecolor='k',label='R_s')
ax.grid()
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Angle'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-9ada5e094190> in <module>
#       1 #Sketch
#       2 fig, ax = plt.subplots(figsize=(10,5))
# ----> 3 plt.errorbar(x=df_p_r_corr['Angle'],y=df_p_r_corr['Coff'],
#       4              fmt='o',mfc='r',mec='r',ms=8,
#       5              xerr=df_p_r_corr['Angle_alpha'],yerr=df_p_r_corr['Err_Coff'],
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Angle'

# %%
#Samlet DF
Final_df = df_p_t_corr[['Angle','Angle_alpha']].copy()
Final_df['Coff_Rp'] = df_p_r_corr['Coff']
Final_df['Coff_Rp_err'] = df_p_r_corr['Err_Coff']
Final_df['Coff_Rs'] = df_s_r_corr['Coff']
Final_df['Coff_Rs_err'] = df_s_r_corr['Err_Coff']

Final_df['Coff_Tp'] = df_p_t_corr['Coff']
Final_df['Coff_Tp_err'] = df_p_t_corr['Err_Coff']
Final_df['Coff_Ts'] = df_s_t_corr['Coff']
Final_df['Coff_Ts_err'] = df_s_t_corr['Err_Coff']

#Final_df.to_csv('Samlet_df.csv', index=False)
