# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
from scipy.optimize import curve_fit
import pandas as pd
import glob
import seaborn as sns

df = pd.read_csv('Data_luft_til_glas.csv')
df
# Out:
#     Angle  Angle_alpha Polarization Reflected/Transmitted  Volt_V  \
# 0       0          0.5            p                     t   4.641
# 1       0          0.5            s                     t   4.547
# 2       5          0.5            p                     t   2.939
# 3       5          0.5            s                     t   2.080
# 4      10          0.5            p                     t   4.222
# ..    ...          ...          ...                   ...     ...
# 69     70          0.5            s                     r   1.007
# 70     75          0.5            p                     t   1.027
# 71     75          0.5            s                     t   0.645
# 72     75          0.5            p                     r   0.459
# 73     75          0.5            s                     r   1.263
#
#     Volt_alpha_mV
# 0           10.56
# 1           10.59
# 2           21.18
# 3           10.59
# 4           19.44
# ..            ...
# 69          14.17
# ...

# %%
sns.scatterplot(data=df,x='Angle',y='Volt_V',hue='Polarization', style='Reflected/Transmitted')
